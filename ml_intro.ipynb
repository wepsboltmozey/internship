# %%
import pandas as pd
import numpy as np

# %%
listA = [1, 2,3,4,5]
datalistA =pd.DataFrame(listA)
listB = [10, 11,31]
datalistB =pd.DataFrame(listB)
pd.merge(datalistA, datalistB, how='inner')
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
df1 = pd.DataFrame({ 'S/N0': ['1','2', '3', '4'],
                    'Name': ['Mark', 'Walter', 'Lydia', 'John'],
                     'Sex': ['Male', 'Non-binary', 'Female', 'male'],
                     'Status':['Prefer not to say', 'taken', 'confidential', 'single']

})

df2 = pd.DataFrame({'S/N0': ['1','2', '3', '4'],'progam': ['BSE', 'EEE', 'BSE', 'BCS'], 'Year of Study': [4, 4, 3, 2],'Age': [24, 23, 22, 23],'semester 1': [4.2, 1.5, 4.0, 2.8],'semester 2': [3.2, 4.5, 4.1, 3.4],
                    })
df2
# Out:
#   S/N0 progam  Year of Study  Age  semester 1  semester 2
# 0    1    BSE              4   24         4.2         3.2
# 1    2    EEE              4   23         1.5         4.5
# 2    3    BSE              3   22         4.0         4.1
# 3    4    BCS              2   23         2.8         3.4

# %%
data =pd.merge(df1, df2, how='inner', on='S/N0')

# %%
std = data['semester 1'].std()
std
# Out:
# 1.2473304828045106

# %%
data2 = data.to_csv('data2.csv')

# %%
randomData = np.random.randint(10,50, size=15)
randomData = pd.DataFrame(randomData, columns=['Random Age'])
randomData
# Out:
#     Random Age
# 0           21
# 1           32
# 2           13
# 3           45
# 4           10
# 5           26
# 6           33
# 7           37
# 8           33
# 9           34
# 10          37
# 11          49
# 12          28
# 13          31
# 14          45

# %%
arr1 = np.array([1,2,3,4])
arr1[1:4:1]
# Out:
# array([2, 3, 4])
